# %% [markdown]
# This notebook should be used to create input files for the first run of convergence test MD simulations

# %%
import os
import json
import matplotlib.pyplot as plt 
from jobflow import SETTINGS
from pymatgen.core.structure import Structure
import numpy as np
from pymatgen.io.vasp import  Kpoints
import os
from fireworks import LaunchPad
from jobflow.managers.fireworks import flow_to_workflow
from atomate2.vasp.powerups import update_user_incar_settings, update_user_potcar_settings, update_user_kpoints_settings
from atomate2.vasp.flows.core import DoubleRelaxMaker
from atomate2.vasp.flows.mp import MPGGADoubleRelaxStaticMaker
from atomate2.vasp.jobs.core import StaticMaker, TightRelaxMaker, RelaxMaker
from atomate2.vasp.jobs.md import MDMaker
import os
from jobflow.settings import JobflowSettings  # Assuming JobflowSettings is imported from jobflow.settings
from pymatgen.io.vasp.sets import MPStaticSet
from atomate2.vasp.sets.mp import MPGGAStaticSetGenerator
# Create a new instance of JobflowSettings
SETTINGS = JobflowSettings()
store = SETTINGS.JOB_STORE
store.connect()
lpad = LaunchPad.auto_load()
from pymatgen.core.structure import Structure
# Out:
# /home/sjonathan/.jobflow.yaml
# {'docs_store': {'type': 'MongoURIStore', 'uri': 'mongodb://sjonathan:sd12ELsT9oziDPq2@82.130.69.206:27017/EuTiO?authSource=admin&readPreference=primary&ssl=false&directConnection=true', 'collection_name': 'outputs'}, 'additional_stores': {'data': {'type': 'GridFSURIStore', 'uri': 'mongodb://sjonathan:sd12ELsT9oziDPq2@82.130.69.206:27017/EuTiO?authSource=admin&readPreference=primary&ssl=false&directConnection=true', 'collection_name': 'outputs_blobs'}}}
# /home/sjonathan/.jobflow.yaml
# {'docs_store': {'type': 'MongoURIStore', 'uri': 'mongodb://sjonathan:sd12ELsT9oziDPq2@82.130.69.206:27017/EuTiO?authSource=admin&readPreference=primary&ssl=false&directConnection=true', 'collection_name': 'outputs'}, 'additional_stores': {'data': {'type': 'GridFSURIStore', 'uri': 'mongodb://sjonathan:sd12ELsT9oziDPq2@82.130.69.206:27017/EuTiO?authSource=admin&readPreference=primary&ssl=false&directConnection=true', 'collection_name': 'outputs_blobs'}}}

# %%
test_structure = Structure.from_file('/home/sjonathan/Downloads/POSCAR')

# %%
from pymatgen.io.vasp.sets import MPRelaxSet
from atomate2.vasp.sets.core import MDSetGenerator
MPSetGGAMPGenerator = MDSetGenerator(structure=test_structure, ensemble="NVT",start_temp=300, end_temp=300, time_step=1, nsteps=10, user_potcar_functional="PBE_64",
    config_dict=MPRelaxSet.CONFIG)
generator = MPSetGGAMPGenerator.write_input(output_dir="test_ours")
# Out:
# <string>:37: BadInputSetWarning: Overriding the POTCAR functional is generally not recommended  as it significantly affects the results of calculations and compatibility with other calculations done with the same input set. Note that some POTCAR symbols specified in the configuration file may not be available in the selected functional.

# %%
from pymatgen.io.vasp.sets import MPRelaxSet
from atomate2.vasp.sets.core import MDSetGenerator
from pymatgen.io.vasp.sets import MPMDSet
MPSetGGAMPGenerator = MDSetGenerator(structure=test_structure, ensemble="NVT",start_temp=300, end_temp=300, time_step=1, nsteps=10, user_potcar_functional="PBE_64")
generator = MPSetGGAMPGenerator.write_input(output_dir="test_atomate2")
# Out:
# /home/sjonathan/anaconda3/envs/fireworks_mp/lib/python3.11/site-packages/pymatgen/io/vasp/sets.py:487: BadInputSetWarning: POTCAR data with symbol Eu_2 is not known by pymatgen to correspond with the selected user_potcar_functional='PBE_64'. This POTCAR is known to correspond with functionals ['PBE_54', 'PBE_52']. Please verify that you are using the right POTCARs!
#   potcar="\n".join(self.potcar_symbols) if potcar_spec else self.potcar,
# /home/sjonathan/anaconda3/envs/fireworks_mp/lib/python3.11/site-packages/pymatgen/io/vasp/sets.py:487: BadInputSetWarning: POTCAR data with symbol Ti_sv is not known by pymatgen to correspond with the selected user_potcar_functional='PBE_64'. This POTCAR is known to correspond with functionals ['PBE_54', 'PBE_52']. Please verify that you are using the right POTCARs!
#   potcar="\n".join(self.potcar_symbols) if potcar_spec else self.potcar,

# %%
from pymatgen.io.vasp.sets import MPMDSet
MPSetGGAMPGenerator = MPMDSet(structure=test_structure, start_temp=300, end_temp=300, time_step=1, nsteps=10, user_potcar_functional="PBE_64",)
generator = MPSetGGAMPGenerator.write_input(output_dir="test_mpmd", )

# %%
def write_input_files(structure, ENCUT):
    """
    Write input files for VASP md calculations compatible with the materials project.
    Only changes to the updated pseudopotentials.
    Args:
        structure (Structure): The structure object for the calculation.
        ENCUT (float): The energy cutoff for the calculation.
    """
    md_maker = MDMaker(input_set_generator=MPGGAStaticSetGenerator, )
    md_maker = update_user_incar_settings(md_maker, {"ENCUT": ENCUT})
    md_maker = update_user_potcar_settings(md_maker, {"POTCAR": "'PBE_64'"})

# %%
    ensemble: str = "nvt"
    start_temp: float = 300
    end_temp: float = 300
    nsteps: int = 1000
    time_step: float = 2
    auto_ispin: bool = True
